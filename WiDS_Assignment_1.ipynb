# %% [markdown]
# # 📌 WiDS Assignment 1: Foundations of Face Recognition
#
# This assignment helps you connect **data handling, image preprocessing, neural network design, and decision logic** — the core components of a Siamese Face Recognition system.
#
# Read the markdown before each code block carefully. It explains **why** the next block exists.

# %% [markdown]
# ## 🧩 Task 1: Organizing Data (Pandas / NumPy)
#
# **Goal:** Learn how image labels and file names are managed using tabular data.

# %%
import pandas as pd
import numpy as np

data = {'Name': ['Alice', 'Bob', 'Alice', 'Charlie'],
        'File': ['a1.jpg', 'b1.jpg', 'a2.jpg', 'c1.jpg']}

# TODO: Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# TODO: Filter the DataFrame to find only 'Alice's images
alice_data = df[df['Name'] == 'Alice']
print(alice_data)
# Out:
#     Name    File
# 0  Alice  a1.jpg
# 2  Alice  a2.jpg

# %% [markdown]
# ## 🧩 Task 2: Image Preprocessing (OpenCV / Matplotlib)
#
# **Goal:** Prepare images in the format required by the Siamese Network (105×105 grayscale, normalized).

# %%
import cv2
import matplotlib.pyplot as plt

# TODO: Read an image and convert to Grayscale
img = cv2.imread('a1.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# TODO: Resize to 105x105 as required by the Siamese Paper
img_resized = cv2.resize(img_gray, (105, 105))

# TODO: Normalize pixel values to be between 0 and 1
img_final = img_resized / 255.0

plt.imshow(img_final, cmap='gray')
plt.title("Ready for the Network!")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-4072499325.py in <cell line: 0>()
#       4 # TODO: Read an image and convert to Grayscale
#       5 img = cv2.imread('a1.jpg')
# ----> 6 img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       7
#       8 # TODO: Resize to 105x105 as required by the Siamese Paper
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## 🧩 Task 3: Building the Twin Network (TensorFlow)
#
# **Goal:** Build the feature extractor used in Siamese Networks.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def create_tower():
    model = models.Sequential([
        # TODO: Add a Convolution layer (64 filters, 10x10 kernel)
        layers.Conv2D(64, (10, 10), activation='relu', input_shape=(105, 105, 1)),

        # TODO: Add Max Pooling (2x2)
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),

        # TODO: Add the final Dense layer (4096 units)
        layers.Dense(4096, activation='sigmoid')
    ])
    return model

my_tower = create_tower()
my_tower.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 96, 96, 64)     │         6,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## 🧩 Task 4: One-Shot Decision Logic (Python)
#
# **Goal:** Convert similarity scores into final predictions.

# %%
def classify_image(similarity_score):
    # TODO: If score > 0.5, it's the same person; else, it's different
# Write your if-else logic here
    if similarity_score > 0.5:
        print(f"Score: {similarity_score} -> Same Person")
    else:
        print(f"Score: {similarity_score} -> Different Person")
# Test your function
classify_image(0.88)
# Out:
# Score: 0.88 -> Same Person
